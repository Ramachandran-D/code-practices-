# %%
import pandas as pd

# %%
data = pd.read_csv('addresses.csv')

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data.head(7)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
# 6   7            7         500 Arbor Road       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US
# 6             CA       94025      US

# %%
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.tail(8)
# Out:
#     id  location_id                   address_1  address_2  \
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# 15  16           16         1161 South Bernardo        NaN
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 13         Redwood City             CA       94063      US
# 14        San Francisco             CA       94110      US
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# ...

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
data[['id', 'address_1']]
# Out:
#     id                   address_1
# 0    1       2600 Middlefield Road
# 1    2            24 Second Avenue
# 2    3            24 Second Avenue
# 3    4            24 Second Avenue
# 4    5            24 Second Avenue
# 5    6           800 Middle Avenue
# 6    7              500 Arbor Road
# 7    8           800 Middle Avenue
# 8    9       2510 Middlefield Road
# 9   10       1044 Middlefield Road
# 10  11         2140 Euclid Avenue.
# 11  12       1044 Middlefield Road
# 12  13         399 Marine Parkway.
# 13  14          660 Veterans Blvd.
# 14  15        1500 Valencia Street
# 15  16         1161 South Bernardo
# 16  17     409 South Spruce Avenue
# 17  18            114 Fifth Avenue
# 18  19         19 West 39th Avenue
# 19  20          123 El Camino Real
# 20  21  2013 Avenue of the fellows

# %%
data[['id', 'address_1', 'state_province']]
# Out:
#     id                   address_1 state_province
# 0    1       2600 Middlefield Road             CA
# 1    2            24 Second Avenue             CA
# 2    3            24 Second Avenue             CA
# 3    4            24 Second Avenue             CA
# 4    5            24 Second Avenue             CA
# 5    6           800 Middle Avenue             CA
# 6    7              500 Arbor Road             CA
# 7    8           800 Middle Avenue             CA
# 8    9       2510 Middlefield Road             CA
# 9   10       1044 Middlefield Road             CA
# 10  11         2140 Euclid Avenue.             CA
# 11  12       1044 Middlefield Road             CA
# 12  13         399 Marine Parkway.             CA
# 13  14          660 Veterans Blvd.             CA
# 14  15        1500 Valencia Street             CA
# 15  16         1161 South Bernardo             CA
# 16  17     409 South Spruce Avenue             CA
# 17  18            114 Fifth Avenue             CA
# ...

# %%
pd.read_csv('contacts.csv')
# Out:
#     id  location_id  organization_id  service_id                     name  \
# 0    1          1.0              NaN         NaN            Susan Houston
# 1    2          1.0              NaN         NaN       Christina Gonzalez
# 2    3          2.0              NaN         NaN             Brenda Brown
# 3    4          3.0              NaN         NaN       Howard Lader, LCSW
# 4    5          4.0              NaN         NaN       Kimberly Pesavento
# 5    6          5.0              NaN         NaN                Joe Bloom
# 6    7          6.0              NaN         NaN              Peter Olson
# 7    8          6.0              NaN         NaN             Bart Charlow
# 8    9          7.0              NaN         NaN             Bart Charlow
# 9   10          7.0              NaN         NaN             Barbara Kalt
# 10  11          8.0              NaN         NaN  Marilyn Baker-Venturini
# 11  12          8.0              NaN         NaN       Graciela Hernandez
# ...

# %%
pd.read_excel("file_example_XLS_50.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\admin\anaconda3\Lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File c:\Users\admin\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
pd.read_excel('SaleData.xlsx')
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
pd.read_excel('SaleData.xlsx', Sheet_name = 'Sheet1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pd.read_excel('SaleData.xlsx', Sheet_name = 'Sheet1')
#
# TypeError: read_excel() got an unexpected keyword argument 'Sheet_name'

# %%
pd.read_excel('SaleData1.xlsx', sheet_name = 'Sheet1', header=None)
# Out:
#            0        1        2          3           4   5    6      7
# 0 2018-02-26  Central  Timothy      David  Cell Phone  27  225   6075
# 1 2018-10-22     East   Martha  Alexander  Cell Phone  64  225  14400
# 2 2018-11-08     East  Douglas      Karen  Cell Phone  15  225   3375
# 3 2019-04-27     East   Martha      Diana  Cell Phone  96  225  21600
# 4 2019-09-27     West  Timothy    Stephen  Cell Phone  76  225  17100

# %%
pd.read_excel('SaleData1.xlsx', sheet_name = 'Sales Data')
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
pd.read_excel('SaleData1.xlsx', sheet_name = 'Sheet1', header=None, names= ['a', 'b','c','d'])
# Out:
#                                                a   b    c      d
# 2018-02-26 Central Timothy David      Cell Phone  27  225   6075
# 2018-10-22 East    Martha  Alexander  Cell Phone  64  225  14400
# 2018-11-08 East    Douglas Karen      Cell Phone  15  225   3375
# 2019-04-27 East    Martha  Diana      Cell Phone  96  225  21600
# 2019-09-27 West    Timothy Stephen    Cell Phone  76  225  17100

# %%
data.to_csv('test.csv')

# %%
data_titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv')

# %%
data_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
