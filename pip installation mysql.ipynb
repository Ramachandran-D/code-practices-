# %%
pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/54/15/98d703a1101e0bfb106e4085f41f937ddca869d16746c076fb818b6f883d/mysql_connector_python-9.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.1 MB 8.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.9/16.1 MB 8.1 MB/s eta 0:00:02
#    -- ------------------------------------- 1.2/16.1 MB 7.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/16.1 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.9/16.1 MB 7.6 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/16.1 MB 7.4 MB/s eta 0:00:02
#    ------ --------------------------------- 2.8/16.1 MB 7.6 MB/s eta 0:00:02
#    -------- ------------------------------- 3.2/16.1 MB 7.6 MB/s eta 0:00:02
# ...

# %%
import mysql
